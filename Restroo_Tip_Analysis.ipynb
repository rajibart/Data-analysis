# %% [markdown]
# <a href="https://colab.research.google.com/github/rajibart/Data-analysis/blob/main/Restroo_Tip_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DATA ANALYSIS PROJECT

# %% [markdown]
# **Project Title: Restroo Tip Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data source: https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

df=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %% [markdown]
# Study the data

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.tail(15)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.sample()
# Out:
#     total_bill  tip   sex smoker   day   time  size
# 86       13.03  2.0  Male     No  Thur  Lunch     2

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 163       13.81  2.00    Male     No  Sun  Dinner     2
# 39        31.27  5.00    Male     No  Sat  Dinner     3
# 171       15.81  3.16    Male    Yes  Sat  Dinner     2
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 33        20.69  2.45  Female     No  Sat  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# # DATA **CLEANING**

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# df=df.dropna()   to delete rows with empty cell
# df=df.fillna(df.mean()) to replace empty data with mean

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# one hot encodeing

# %%
df['sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: object

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
count_gender=df['sex'].value_counts()

# %%
count_gender
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.barplot(count_gender)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
mapping={"Female":0,"Male":1}
df['sex']=df['sex'].map(mapping)

# %%
df['sex']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 239    1
# 240    0
# 241    1
# 242    1
# 243    0
# Name: sex, Length: 244, dtype: int64

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    int64
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip         sex        size
# count  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    0.643443    2.569672
# std      8.902412    1.383638    0.479967    0.951100
# min      3.070000    1.000000    0.000000    1.000000
# 25%     13.347500    2.000000    0.000000    2.000000
# 50%     17.795000    2.900000    1.000000    2.000000
# 75%     24.127500    3.562500    1.000000    3.000000
# max     50.810000   10.000000    1.000000    6.000000

# %%
df['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
count_addition=df['smoker'].value_counts()

# %%
count_addition
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.barplot(count_addition)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
mapping={"No":0,"Yes":1}
df['smoker']=df['smoker'].map(mapping)

# %%
df['smoker']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 239    0
# 240    1
# 241    1
# 242    0
# 243    0
# Name: smoker, Length: 244, dtype: int64

# %%
count_day=df['day'].value_counts()
count_day
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.barplot(count_day)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
mapping={"Fri":0,"Thur":1,"Sun":2,"Sat":3}
df['day']=df['day'].map(mapping)

# %%
df
# Out:
#      total_bill   tip     sex  smoker  day    time  size
# 0         16.99  1.01  Female       0    2  Dinner     2
# 1         10.34  1.66    Male       0    2  Dinner     3
# 2         21.01  3.50    Male       0    2  Dinner     3
# 3         23.68  3.31    Male       0    2  Dinner     2
# 4         24.59  3.61  Female       0    2  Dinner     4
# ..          ...   ...     ...     ...  ...     ...   ...
# 239       29.03  5.92    Male       0    3  Dinner     3
# 240       27.18  2.00  Female       1    3  Dinner     2
# 241       22.67  2.00    Male       1    3  Dinner     2
# 242       17.82  1.75    Male       0    3  Dinner     2
# 243       18.78  3.00  Female       0    1  Dinner     2
#
# [244 rows x 7 columns]

# %%
count_time=df['time'].value_counts()
count_time
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
sns.barplot(count_time)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
mapping={"Lunch":0,"Dinner":1}
df['time']=df['time'].map(mapping)

# %%
df
# Out:
#      total_bill   tip     sex  smoker  day  time  size
# 0         16.99  1.01  Female       0    2     1     2
# 1         10.34  1.66    Male       0    2     1     3
# 2         21.01  3.50    Male       0    2     1     3
# 3         23.68  3.31    Male       0    2     1     2
# 4         24.59  3.61  Female       0    2     1     4
# ..          ...   ...     ...     ...  ...   ...   ...
# 239       29.03  5.92    Male       0    3     1     3
# 240       27.18  2.00  Female       1    3     1     2
# 241       22.67  2.00    Male       1    3     1     2
# 242       17.82  1.75    Male       0    3     1     2
# 243       18.78  3.00  Female       0    1     1     2
#
# [244 rows x 7 columns]

# %%
df.describe()
# Out:
#        total_bill         tip      smoker         day        time        size
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    0.381148    1.946721    0.721311    2.569672
# std      8.902412    1.383638    0.486667    0.960768    0.449276    0.951100
# min      3.070000    1.000000    0.000000    0.000000    0.000000    1.000000
# 25%     13.347500    2.000000    0.000000    1.000000    0.000000    2.000000
# 50%     17.795000    2.900000    0.000000    2.000000    1.000000    2.000000
# 75%     24.127500    3.562500    1.000000    3.000000    1.000000    3.000000
# max     50.810000   10.000000    1.000000    3.000000    1.000000    6.000000

# %%
df.isnull().sum()
# df=df.dropna()   to delete rows with empty cell
# df=df.fillna(df.mean()) to replace empty data with mean
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
count_size=df['size'].value_counts()
count_size
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.barplot(count_size)
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
count_tip=df['tip'].value_counts()
count_tip
# Out:
# tip
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: count, Length: 123, dtype: int64

# %%
sns.barplot(count_tip)
# Out:
# <Axes: xlabel='tip', ylabel='count'>

# %%
df["tip"]
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
plt.hist(df['tip'])
plt.xlabel("tip")
plt.ylabel("count")
plt.title("tip distribution")
# Out:
# Text(0.5, 1.0, 'tip distribution')

# %%
sns.boxplot(df['tip'])
# Out:
# <Axes: ylabel='tip'>

# %%
count_total_bill=df['total_bill'].value_counts()
count_total_bill
# Out:
# total_bill
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: count, Length: 229, dtype: int64

# %%
sns.barplot(count_total_bill)
# Out:
# <Axes: xlabel='total_bill', ylabel='count'>

# %%
plt.hist(df['total_bill'],color="green",alpha=0.5,bins=50)
plt.xlabel("total_bill")
plt.ylabel("count")
plt.title("total_bill distribution")
# Out:
# Text(0.5, 1.0, 'total_bill distribution')
